# %%
num_epochs = 10

# Define the lists to store the loss and accuracy per epoch
train_losses = [0.9225, 0.6297, 0.5247, 0.4217, 0.2481, 0.1311, 0.0814, 0.0481, 0.1263, 0.0431]
train_accs = [0.6231, 0.7545, 0.7973, 0.8428, 0.9126, 0.9546, 0.9728, 0.9823, 0.9652, 0.9875]
test_losses = [0.7006, 0.6889, 0.6523, 0.6523, 0.7849, 0.8257, 0.9493, 1.0419, 0.8328, 0.9769]
test_accs = [0.7254, 0.7292, 0.7618, 0.7655, 0.7699, 0.8038, 0.8025, 0.8006, 0.8107, 0.8201]

# Plot the loss and accuracy per epoch
import matplotlib.pyplot as plt

epochs = range(1, num_epochs+1)

plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
plt.plot(epochs, train_losses, label='Train')
plt.plot(epochs, test_losses, label='Test')
plt.title('Loss per Epoch')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1,2,2)
plt.plot(epochs, train_accs, label='Train')
plt.plot(epochs, test_accs, label='Test')
plt.title('Accuracy per Epoch')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.show()
